# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit  # import the curve fitting function
# %matplotlib inline

# %%
xspace = np.linspace(-10,12,1000)

# %%
def G(x,mu,sigma):
    return 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (x - mu)**2 / (2 * sigma**2))

# %%
plt.figure(figsize=(10,5))
plt.plot(xspace,np.array([G(entry,0,1) for entry in xspace]));
plt.ylim(0,.5);
plt.xlabel('x');
plt.ylabel('Gaussian Distribution');
plt.text(-7,.4, '$X_{avg}$ = 0 ',size=20);
plt.text(-7,.3, '$\sigma$ = 1 ',size=20);

# %%
plt.figure(figsize=(10,5))
plt.plot(xspace,np.array([G(entry,0,2) for entry in xspace]));
plt.ylim(0,.5);
plt.xlabel('x');
plt.ylabel('Gaussian Distribution');
plt.text(-7,.4, '$X_{avg}$ = 0 ',size=20);
plt.text(-7,.3, '$\sigma$ = 2 ',size=20);

# %%
plt.figure(figsize=(10,5))
plt.plot(xspace,np.array([G(entry,5,2) for entry in xspace]));
plt.ylim(0,.5);
plt.xlabel('x');
plt.ylabel('Gaussian Distribution');
plt.text(-5,.4, '$X_{avg}$ = 0 ',size=20);
plt.text(-5,.3, '$\sigma$ = 2 ',size=20);

# %% [markdown]
# Increasing the standard deviation broadens the distrubution but the total area under the curve must remain the same. Changing the average value for x only causes translation.
